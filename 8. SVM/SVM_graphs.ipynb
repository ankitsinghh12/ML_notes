# %% [markdown]
# # Support Vector Machine

# %% [markdown]
# ## Visualizing a basic plot

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ### lets have a look at the plot

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ### There are multiple hyper planes separating positives from negatives.

# %% [markdown]
# ## But where is the best hyper plane?

# %% [markdown]
# **KEY IDEA**: SVM tries to find a hyperplane that separates **+ves** from **-ves** as widely as possible.
#
# Also known as **MARGIN MAXIMIZING** hyper plane.
#
# Lets look at this plane. Is this the best hyperplane?

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# ### Lets try to draw a plane parallel to original plane and lets try to move it towards +ve points.

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# ### Similarly for -ve points.

# %% [markdown]
# ![5.png](attachment:5.png)

# %% [markdown]
# ### We will end up getting this: (Separating, +ve & -ve Hyperplane)

# %% [markdown]
# ![6.png](attachment:6.png)

# %% [markdown]
# # Margin & Support Vectors

# %% [markdown]
# Now lets look at the Magin.

# %% [markdown]
# ![7.png](attachment:7.png)

# %% [markdown]
# Circled points are called SUPPORT VECTORS.

# %% [markdown]
# ![8.png](attachment:8.png)

# %% [markdown]
# ## MATHEMATICAL FORMULATION

# %% [markdown]
# ![Screenshot%202022-09-03%20075753.jpg](attachment:Screenshot%202022-09-03%20075753.jpg)

# %% [markdown]
# ## Intuition: How to actually find the Margin Maximizing Hyperplane?
#
# Lets first understand the idea behind Convex Hull.
#
# Lets look at some shapes and understand what a convex hull is.

# %% [markdown]
# ![convex-hull.png](attachment:convex-hull.png)

# %% [markdown]
# ### Lets now try to find margin maximizing Hyperplane using previous example.

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# **STEP-1** Draw the convex hull for +ve and -ve points.

# %% [markdown]
# ![9.png](attachment:9.png)

# %% [markdown]
# **STEP-2** Find the shortest line connecting these hulls.

# %% [markdown]
# ![10.png](attachment:10.png)

# %% [markdown]
# **STEP-3** Bisect the line. i.e break it into two equal parts

# %% [markdown]
# ![11.png](attachment:11.png)
